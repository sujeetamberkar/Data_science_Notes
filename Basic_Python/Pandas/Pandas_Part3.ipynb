# %%
import  pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
s=df['Name'][0:10]

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
# How to give coustomized index
l=['One',"Two",'Three','Four','Five','Six',"Seven",'Eight','Nine',"Ten"]
s1=pd.Series(list(s),index=l)

# %%
s[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s1["One"]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s1.append("Abhi")
# Out:
# /tmp/ipykernel_648/1903573274.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s1.append("Abhi")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 s1.append("Abhi")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:3140, in Series.append(self, to_append, ignore_index, verify_integrity)
#    3059 """
#    3060 Concatenate two or more Series.
#    3061
#    (...)
#    3130 ValueError: Indexes have overlapping values: [0, 1, 2]
#    3131 """
#    3132 warnings.warn(
#    3133     "The series.append method is deprecated "
#    3134     "and will be removed from pandas in a future version. "
#    (...)
#    3137     stacklevel=find_stack_level(),
#    3138 )
# -> 3140 return self._append(to_append, ignore_index, verify_integrity)
#
# ...

# %%
s1.append(s)
# Out:
# /tmp/ipykernel_648/3679909265.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s1.append(s)
# One                                Braund, Mr. Owen Harris
# Two      Cumings, Mrs. John Bradley (Florence Briggs Th...
# Three                               Heikkinen, Miss. Laina
# Four          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Five                              Allen, Mr. William Henry
# Six                                       Moran, Mr. James
# Seven                              McCarthy, Mr. Timothy J
# Eight                       Palsson, Master. Gosta Leonard
# Nine     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Ten                    Nasser, Mrs. Nicholas (Adele Achem)
# 0                                  Braund, Mr. Owen Harris
# 1        Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                   Heikkinen, Miss. Laina
# ...

# %%
s4=pd.Series([3,4,5,6], index=[2,4,6,8])

# %%
s5=pd.Series([34,32,33],index=[9,1,3])

# %%
a=s5.append(s4)
# Out:
# /tmp/ipykernel_648/3080587630.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a=s5.append(s4)

# %%
a
# Out:
# 9    34
# 1    32
# 3    33
# 2     3
# 4     4
# 6     5
# 8     6
# dtype: int64

# %%
a[9]
# Out:
# 34

# %%
# Multiplication based on named index
s4 *s5
# Out:
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 6   NaN
# 8   NaN
# 9   NaN
# dtype: float64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("Survived", axis = 1, inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df.drop(2, inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# 5              6       3                                   Moran, Mr. James
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
# You can search via name 
df.set_index("Name", inplace=True)

# %%
df
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Braund, Mr. Owen Harris                                       1       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4       1
# Allen, Mr. William Henry                                      5       3
# Moran, Mr. James                                              6       3
# ...                                                         ...     ...
# Montvila, Rev. Juozas                                       887       2
# Graham, Miss. Margaret Edith                                888       1
# Johnston, Miss. Catherine Helen "Carrie"                    889       3
# Behr, Mr. Karl Howell                                       890       1
# Dooley, Mr. Patrick                                         891       3
#
#                                                        Sex   Age  SibSp  \
# Name
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  PassengerId  Pclass  \
# 0                              Braund, Mr. Owen Harris            1       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2       1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4       1
# 3                             Allen, Mr. William Henry            5       3
# 4                                     Moran, Mr. James            6       3
# ..                                                 ...          ...     ...
# 885                              Montvila, Rev. Juozas          887       2
# 886                       Graham, Miss. Margaret Edith          888       1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889       3
# 888                              Behr, Mr. Karl Howell          890       1
# 889                                Dooley, Mr. Patrick          891       3
#
# ...

# %%
d={'keys1':[1,2,3,4],
   'keys2':[10,20,40,30]
  }

# %%
a=pd.DataFrame(d)
a
# Out:
#    keys1  keys2
# 0      1     10
# 1      2     20
# 2      3     40
# 3      4     30
