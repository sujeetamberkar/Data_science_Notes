# %%
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

"""
Flask Framework is a lightweight and flexible web framework written in Python. Its advantages include simplicity, 
lightweight nature, flexibility, scalability, extensibility, testing support, and a strong community. 
Flask allows developers to quickly get started, choose their own tools and libraries, and easily 
customize and extend the framework based on project requirements.

Advantages
    Simplicity: Flask is easy to understand and get started with.
    Lightweight: It has a small codebase and minimal dependencies.
    Flexibility: Developers have the freedom to choose and integrate additional tools and libraries as needed.
    Scalability: Flask can handle projects of varying sizes and complexities.
    Extensibility: A wide range of extensions are available to add functionality to Flask applications.
    Testing Support: Flask provides built-in tools for testing web applications.
    Documentation and Community: Flask has comprehensive documentation and an active community for support and collaboration.
"""
# Out:
# '\nFlask Framework is a lightweight and flexible web framework written in Python. Its advantages include simplicity, \nlightweight nature, flexibility, scalability, extensibility, testing support, and a strong community. \nFlask allows developers to quickly get started, choose their own tools and libraries, and easily \ncustomize and extend the framework based on project requirements.\n\nAdvantages\n    Simplicity: Flask is easy to understand and get started with.\n    Lightweight: It has a small codebase and minimal dependencies.\n    Flexibility: Developers have the freedom to choose and integrate additional tools and libraries as needed.\n    Scalability: Flask can handle projects of varying sizes and complexities.\n    Extensibility: A wide range of extensions are available to add functionality to Flask applications.\n    Testing Support: Flask provides built-in tools for testing web applications.\n    Documentation and Community: Flask has comprehensive documentation and an acti
# ...

# %%
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

from flask import Flask, redirect,request
# https://orange-receptionist-jdbiz.pwskills.app:5000/test2/test2?x=4
app = Flask(__name__)

@app.route("/sujeet")
def sujeet():
    return  """ 'Hello World!!.' """

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.28:5000
# Press CTRL+C to quit

# %%
from IPython.display import Image
Image(filename='FLASK_SS.png')

# %%
# Q3. What is App routing in Flask? Why do we use app routes?

"""
App routing in Flask involves mapping URLs to functions using the @app.route() decorator. 
We use app routes to handle URL requests, create RESTful APIs, build dynamic web applications, modularize code, 
and pass parameters through URLs. App routing in Flask provides flexibility and power in defining endpoint behavior.
"""
# Out:
# '\nApp routing in Flask involves mapping URLs to functions using the @app.route() decorator. \nWe use app routes to handle URL requests, create RESTful APIs, build dynamic web applications, modularize code, \nand pass parameters through URLs. App routing in Flask provides flexibility and power in defining endpoint behavior.\n'

# %%
"""
Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and 
a “/”
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999
"""
from flask import Flask, redirect,request
# https://orange-receptionist-jdbiz.pwskills.app:5000/
app = Flask(__name__)

@app.route("/")
def hello_world():
    return """ <p>Company Name:
    ABC Corporation </p>
    <p>Location: India</p> 
    <p>Contact Detail: 999-999-9999</p>"""

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'


if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.28:5000
# Press CTRL+C to quit

# %%
from IPython.display import Image
Image(filename='Q4_Main.png')

# %%
Image(filename='Q4_Welcome.png')

# %%
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.
"""
Flask's url_for() function is used for URL building. It accepts the name of a function as its first argument, and any number of 
keyword arguments. Each keyword argument is then used as a variable part in the function’s rule.
Here is a simple Python Flask application code that demonstrates the working of the url_for() function:
"""

from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return 'Home Page'

@app.route('/hello/<name>')
def hello(name):
    return 'Hello, {}'.format(name)

@app.route('/test')
def test_url_for():
    # It generates "/", the URL for index function
    print(url_for('index'))

    # It generates "/hello/john", the URL for hello function with argument name=john
    print(url_for('hello', name='john'))

    return 'Check your console for the printed URLs.'

if __name__ == '__main__':
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.28:5000
# Press CTRL+C to quit
